# %%
name=input("Enter your Names")
weight=float(input("Enter your weight in kg:"))
height=float(input("Enter your height in cm:"))
height_m=height/100
BMI=weight/(height_m**2)
print('Your BMI is:',round(BMI,2))#Rounding it off to to 2dp
if BMI>0:
    if (BMI<18.00):
        print(name+", You are underweight")
    elif(BMI<=24.00):
       print(name+",You are normal weight")
    elif(BMI<29.00):
       print(name+",You are overweight")
    elif(BMI<34.00):
       print(name+",You are obese")
    elif(BMI<39.00):
       print(name+",You are severly obese")
    else:
       print(name+",Please see a doctor")
else:
    print("Enter valid input")
# Out:
# Enter your Names Linda Musundi
# Enter your weight in kg: 65
# Enter your height in cm: 168
# Your BMI is: 23.03
# Linda Musundi,You are normal weight
